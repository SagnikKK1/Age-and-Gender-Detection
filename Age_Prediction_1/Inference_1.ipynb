# %%
cd /content/Age-and-Gender-Detection_GC/Age_Prediction_1
# Out:
# /content/Age-and-Gender-Detection_GC/Age_Prediction_1

# %%
import shutil
shutil.copy("/content/drive/MyDrive/gc_ml_hackathon/ESPCN_x3.pb","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/checkpoint")
shutil.copy("/content/drive/MyDrive/gc_ml_hackathon/pretrained.pt","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/checkpoint")
shutil.copy("/content/drive/MyDrive/gc_ml_hackathon/ckpt_max.pth","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/checkpoint")
shutil.copy("/content/drive/MyDrive/gc_ml_hackathon/weights.h5","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/checkpoint")
# Out:
# '/content/Age-and-Gender-Detection_GC/Age_Prediction_1/checkpoint/weights.h5'

# %%
shutil.copy("/content/vid_1.mp4","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/video")
shutil.copy("/content/vid_2.mp4","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/video")
shutil.copy("/content/vid_3.mp4","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/video")
# Out:
# '/content/Age-and-Gender-Detection_GC/Age_Prediction_1/video/vid_3.mp4'

# %%
shutil.copy("/content/img_1.jpg","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/img")
shutil.copy("/content/img_2.jpg","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/img")
shutil.copy("/content/img_3.jpg","/content/Age-and-Gender-Detection_GC/Age_Prediction_1/img")
# Out:
# '/content/Age-and-Gender-Detection_GC/Age_Prediction_1/img/img_3.jpg'

# %% [markdown]
# # Age Prediction from Video

# %%
# !python predict.py --type video
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100% 160M/160M [00:02<00:00, 68.1MB/s]
# ...

# %%
# !python predict.py --type video
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Load successful
# Enter the filename: vid_2.mp4
# Resolution: 480, 854
# Frames Per Second = 29.97002997002997
# Number of Frames = 984
# Duration (seconds) = 32.8328
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ...

# %%
# !python predict.py --type video
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Load successful
# Enter the filename: vid_3.mp4
# Resolution: 720, 1280
# Frames Per Second = 23.976023976023978
# Number of Frames = 98
# Duration (seconds) = 4.087416666666666
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# ...

# %% [markdown]
# # Age Prediction from Image

# %%
# !python predict.py --type image
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Load successful
# Enter the image filename: img_1.jpg
# [ WARN:0@12.429] global net_impl.cpp:178 setUpNet DNN module was not built with CUDA backend; switching to CPU
# ...

# %%
# !python predict.py --type image
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Load successful
# Enter the image filename: img_2.jpg
# [ WARN:0@8.112] global net_impl.cpp:178 setUpNet DNN module was not built with CUDA backend; switching to CPU
# ...

# %%
# !python predict.py --type image
# Out:
# GPU
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Load successful
# Enter the image filename: img_3.jpg
# [ WARN:0@13.831] global net_impl.cpp:178 setUpNet DNN module was not built with CUDA backend; switching to CPU
# ...
